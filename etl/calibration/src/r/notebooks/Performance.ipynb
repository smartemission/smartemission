# %%
library(tidyverse)
# Out:
# Loading tidyverse: ggplot2
# Loading tidyverse: tibble
# Loading tidyverse: tidyr
# Loading tidyverse: readr
# Loading tidyverse: purrr
# Loading tidyverse: dplyr
# Warning message:
# “package ‘readr’ was built under R version 3.2.5”Warning message:
# “package ‘dplyr’ was built under R version 3.2.5”Conflicts with tidy packages ---------------------------------------------------
# filter(): dplyr, stats
# lag():    dplyr, stats

# %%
file_perf_03 = "/home/pieter/Documents/GemeenteNijmegen/smartemission/etl/calibration/io/performance/001475672895_O3_Waarden_target_pred.csv"
file_perf_no2 = "/home/pieter/Documents/GemeenteNijmegen/smartemission/etl/calibration/io/performance/001475752478_NO2_Waarden_target_pred.csv"

# %%
perf_o3 <- read.csv(file_perf_03)
head(perf_o3)
# Out:
#   X      prediction target
# 1 289635 83.94015    73.46200
# 2 228136 23.45819    36.67250
# 3 241833 61.35357    60.82500
# 4 255244 99.87769   101.82000
# 5  92613 44.68922    47.56467
# 6  20213 38.37333    28.09850

# %%
ggplot(perf_o3, aes(prediction, target)) + geom_point()
# Out:
# plot without title
